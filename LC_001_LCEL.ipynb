# %% [markdown]
# # 환경 변수 로드

# %%
# %pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# %pip install langchain langchain-openai

# %% [markdown]
# # 1-1

# %%
from langchain_openai import ChatOpenAI

# 채팅 모델 초기화
llm = ChatOpenAI(model='gpt-4o-mini')

# 모델에 직접 텍스트를 입력
result = llm.invoke("김치찌개에 대한 레시피를 3단계로 설명해주세요.")

# 답변을 출력 
print(result.content)
# Out:
# 김치찌개를 만드는 간단한 3단계 레시피를 소개하겠습니다!
#
# ### 1단계: 재료 준비하기
# - **주재료**: 잘 익은 김치 200g, 두부 1/2모, 돼지고기(삼겹살 또는 목살) 150g
# - **부재료**: 대파 1대, 양파 1/2개, 마늘 2쪽, 고춧가루 1~2큰술, 국간장 1큰술
# - **물**: 3컵(약 750ml)
#
# ### 2단계: 재료 볶기
# 1. 팬에 돼지고기를 넣고 중불에서 볶아 기름이 나올 때까지 익힙니다.
# 2. 돼지고기가 익으면 잘 익은 김치와 양파, 마늘을 넣고 함께 볶습니다. 김치가 고르게 익을 때까지 5분 정도 볶아주세요.
# 3. 볶은 재료에 고춧가루와 국간장을 넣고 한 번 더 섞어준 후, 물 3컵을 부어 끓입니다.
#
# ### 3단계: 끓이기 및 나누기
# 1. 끓기 시작하면 두부를 큐브 모양으로 잘라 넣고, 대파를 송송 썰어 넣습니다.
# 2. 중불에서 10~15분 정도 끓여 재료들이 잘 어우러지도록 합니다. 소금으로 간을 맞추세요.
# 3. 완성된 김치찌개는 그릇에 담아 맛있게 드세요!
#
# 이렇게 간단하게 김치찌개를 만들 수 있습니다. 즐거운 요리 시간 되세요!

# %% [markdown]
# # 1-2

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

# 채팅 모델 초기화
llm = ChatOpenAI(model='gpt-4o-mini')

# 프롬프트 템플릿 정의
prompt = ChatPromptTemplate.from_template("{food}에 대한 레시피를 3단계로 설명해주세요.")

# prompt + llm 조합으로 체인을 구성 
chain = prompt | llm

# 체인 실행
result = chain.invoke({"food": "비빔밥"})

# 결과 출력
print("답변: ", result.content)
# Out:
# 답변:  비빔밥은 한국의 전통 음식으로, 다양한 재료를 섞어 먹는 밥 요리입니다. 아래는 비빔밥을 만드는 간단한 3단계 레시피입니다.
#
# ### 단계 1: 재료 준비
# 주재료:
# - 밥 (일반적으로 흰 쌀밥)
# - 각종 나물 (시금치, 고사리, 콩나물 등)
# - 고추장
# - 계란 (프라이 또는 반숙)
# - 참기름
# - 소금
# - 채소 (당근, 오이, 버섯 등)
#
# ### 단계 2: 나물과 채소 조리
# 1. 각종 나물과 채소를 깨끗이 씻은 후, 끓는 물에 소금을 약간 넣고 데칩니다.
# 2. 데친 나물은 찬물에 헹궈 물기를 제거한 후, 참기름, 소금으로 간을 합니다.
# 3. 당근과 버섯은 채 썰어서 팬에 볶아줍니다.
#
# ### 단계 3: 비빔밥 완성
# 1. 그릇에 따뜻한 밥을 담고, 준비한 나물과 채소를 예쁜 모양으로 올려줍니다.
# 2. 중간에 계란 프라이를 올리고, 고추장을 넣습니다.
# 3. 마지막으로 참기름을 뿌리고, 모든 재료를 잘 비빈 후 즐기면 됩니다.
#
# 맛있게 드세요!

# %% [markdown]
# # 1-3

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# 채팅 모델 초기화
llm = ChatOpenAI(model='gpt-4o-mini')

# 프롬프트 템플릿 정의
prompt = ChatPromptTemplate.from_template(
    """
    {음식}의 주재료를 3가지만 나열하세요.
    각 재료는 쉼표로 구분하세요.
    """
    )

# 체인 생성
chain = prompt | llm | StrOutputParser()

# 체인 실행
result = chain.invoke({"음식": "김치찌개"})
print(result)
# Out:
# 배추, 두부, 돼지고기

# %%
print(type(result))  # <class 'str'>
# Out:
# <class 'langchain_core.messages.base.TextAccessor'>
